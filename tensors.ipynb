# %% [markdown]
# <a href="https://colab.research.google.com/github/kanishkdeep01/deep_learning/blob/main/tensors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
tensor_1  = torch.tensor([1.0,2.0,3.0])

# %%
tensor_2 = torch.zeros(2,3)

# %%
print(tensor_2)
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])

# %%
tensor_2 = torch.zeros(2,2)

# %%
print(tensor_2)
# Out:
# tensor([[0., 0.],
#         [0., 0.]])

# %%
tensor_3 = torch.rand(3,3)

# %%
print(tensor_3)
# Out:
# tensor([[0.4812, 0.3330, 0.9838],
#         [0.3456, 0.2441, 0.4192],
#         [0.8669, 0.6979, 0.0051]])

# %%
result = tensor_2 + tensor_2

# %%
print(tensor_2)
# Out:
# tensor([[0., 0.],
#         [0., 0.]])

# %%
result1 = torch.matmul(tensor_1,tensor_3)

# %%
print(result1)
# Out:
# tensor([3.7731, 2.9150, 1.8374])

# %%
x = torch.tensor(3.0,requires_grada = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_744/1973570535.py in <cell line: 0>()
# ----> 1 x = torch.tensor(3.0,requires_grada = True)
#
# NameError: name 'torch' is not defined
