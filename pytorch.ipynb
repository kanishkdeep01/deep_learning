# %% [markdown]
# <a href="https://colab.research.google.com/github/kanishkdeep01/deep_learning/blob/main/pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
import numpy as np

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
print(device)
# Out:
# cuda

# %%
numpy_array = np.array([[1.0,2.0],[3.0, 4.0]])

# %%
pytorch_tensor = torch.tensor([[1.0,2.0],[3.0,4.0]])

# %%
print(pytorch_tensor)
# Out:
# tensor([[1., 2.],
#         [3., 4.]])

# %%
print(numpy_array)
# Out:
# [[1. 2.]
#  [3. 4.]]

# %%
gpu_tensor = pytorch_tensor.to(device)

# %%
print(gpu_tensor)
# Out:
# tensor([[1., 2.],
#         [3., 4.]], device='cuda:0')
