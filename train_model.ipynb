# %% [markdown]
# <a href="https://colab.research.google.com/github/kanishkdeep01/deep_learning/blob/main/train_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
model = Somexyzmodel()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_893/2897140836.py in <cell line: 0>()
# ----> 1 model = Somexyzmodel()
#
# NameError: name 'Somexyzmodel' is not defined

# %%
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(),lr = 0.01)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_893/1310410879.py in <cell line: 0>()
#       1 criterion = nn.MSELoss()
# ----> 2 optimizer = optim.SGD(model.parameters(),lr = 0.01)
#
# NameError: name 'model' is not defined

# %%
for epoch in range(100):
  for inputs,labels in my_dataset:
    ouputs = model(inputs)
    loss = criterion(outputs,labels)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

if epoch%10 == 0:
  print(f'Epoch{epoch},Loss: {loss.item()}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_893/3043952746.py in <cell line: 0>()
#       1 for epoch in range(100):
# ----> 2   for inputs,labels in my_dataset:
#       3     ouputs = model(inputs)
#       4     loss = criterion(outputs,labels)
#       5     optimizer.zero_grad()
#
# NameError: name 'my_dataset' is not defined
