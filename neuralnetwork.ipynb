# %% [markdown]
# <a href="https://colab.research.google.com/github/kanishkdeep01/deep_learning/blob/main/neuralnetwork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
x = torch.tensor(2.0 , requires_grad = True)

# %%
print(x)
# Out:
# tensor(2., requires_grad=True)

# %%
y = x**2 + 5*x

# %%
print(y)
# Out:
# tensor(14., grad_fn=<AddBackward0>)

# %%
y.backward()

# %%
print(y)
# Out:
# tensor(14., grad_fn=<AddBackward0>)

# %%
print(x)
# Out:
# tensor(2., requires_grad=True)

# %%
print(x.grad)
# Out:
# tensor(9.)
